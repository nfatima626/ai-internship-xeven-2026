# %% [markdown]
# # AI Internship - Day 1
#
# ## Environment Setup and First Python Program
#
# **Name:** Noor Fatima
#
# **Date:** 29 June 2026

# %% [markdown]
# ## Objective
#
# The objective of this task is to set up the Python development environment, install the required tools, write the first Python program, and verify that everything is working correctly.

# %% [markdown]
# ## Software Installed
#
# - Python 3.13.14
# - Visual Studio Code
# - Jupyter Notebook

# %%
print("Hi, this is Noor Fatima, future AI engineer!")
# Out:
# Hi, this is Noor Fatima, future AI engineer!

# %% [markdown]
# ## Output
#
# The Python script executed successfully and displayed the personalized greeting.

# %% [markdown]
# ## Troubleshooting
#
# Initially, Jupyter Notebook installation failed because VS Code was using the MSYS2 Python interpreter.
#
# Solution:
# - Installed the official Python 3.13.14 from python.org.
# - Selected the correct Python interpreter in VS Code.
# - Successfully installed Jupyter Notebook.

# %% [markdown]
# ## Installing NumPy using UV
#
# Command:
#
# uv add numpy
#
# Purpose:
# Installed NumPy inside the project's virtual environment. UV automatically updated the `pyproject.toml` file and created the `uv.lock` file to ensure reproducible dependency management.

# %%
import numpy as np

print("NumPy Version:", np.__version__)
# Out:
# NumPy Version: 2.5.0

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\AT\Downloads\ai-internship-xeven-2026\day01\.venv\Scripts\python.exe

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])
print(a)
print(type(a))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>
